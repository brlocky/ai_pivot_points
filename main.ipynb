# %%
from main import MyProgram


p = MyProgram()

p.run()
# Out:
# Model loaded.
# Ready

# %%
for i in range(0, 3):
    p.run_train('csv/learn/output_101.csv')
# Out:
# 0.12554752826690674
# 0.009851624257862568
# 0.02545449696481228
# 0.07012227177619934
# 0.005464068613946438
# 0.009232141077518463
# 0.05718805268406868
# 0.004438147880136967
# 0.006894334219396114

# %%
for i in range(0, 100):
    p.run_learn()
    print('-----', i)

# %%
p.run_predict_all()
# Out:
# 1/1 [==============================] - 0s 341ms/step
# Accuracy: 33.33333333333333%
# 3/3 [==============================] - 0s 5ms/step
# Accuracy: 40.0%
# 3/3 [==============================] - 0s 4ms/step
# Accuracy: 28.57142857142857%
# 2/2 [==============================] - 0s 4ms/step
# Accuracy: 22.22222222222222%
# 3/3 [==============================] - 0s 7ms/step
# Accuracy: 35.16483516483517%
# 2/2 [==============================] - 0s 7ms/step
# Accuracy: 29.82456140350877%
# 4/4 [==============================] - 0s 6ms/step
# Accuracy: 31.30434782608696%
# 2/2 [==============================] - 0s 3ms/step
# Accuracy: 22.22222222222222%
# 1/1 [==============================] - 0s 14ms/step
# Accuracy: 76.92307692307693%
# 3/3 [==============================] - 0s 5ms/step
# Accuracy: 25.37313432835821%
# 2/2 [==============================] - 0s 3ms/step
# Accuracy: 20.0%
# 2/2 [==============================] - 0s 7ms/step
# Accuracy: 28.333333333333332%
# ...
